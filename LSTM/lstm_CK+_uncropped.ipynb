# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
from keras import backend as K
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, LSTM, TimeDistributed, Conv2D, MaxPooling2D

# %%
# Use GPU
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %%
np.random.seed(10)

path = "/content/drive/MyDrive/CISC499/CK+_Complete"

dataDirectoryList = os.listdir(path)
imageDataList = []
labels = []
labelDictionary = {"anger":0, "contempt":1, "disgust":2, "fear":3, "happy":4, "sadness":5, "surprise":6}

# %%
for dataset in dataDirectoryList:
  imageList = os.listdir(path + "/" + dataset)
  print("Loaded the images of dataset-" + '{}\n'.format(dataset))
  for image in imageList:
    imagepath = path + "/" + dataset + "/" + image
    inputImage = cv2.imread(imagepath)
    inputImage = cv2.resize(inputImage, (48, 48))   # Resize images to 48x48
    imageDataList.append(inputImage)
    labels.append(labelDictionary[dataset])    # Label of each image is the name of its folder
# Out:
# Loaded the images of dataset-sadness
#
# Loaded the images of dataset-disgust
#
# Loaded the images of dataset-happy
#
# Loaded the images of dataset-fear
#
# Loaded the images of dataset-contempt
#
# Loaded the images of dataset-anger
#
# Loaded the images of dataset-surprise

# %%
lenSequence = 5
# Creates sequences of 5 images and adds them to a list.
newImageDataList = []
for i in range(0, len(imageDataList), lenSequence):
  newList = []
  image1 = imageDataList[i-5]
  image2 = imageDataList[i-4]
  image3 = imageDataList[i-3]
  image4 = imageDataList[i-2]
  image5 = imageDataList[i-1]
  newList.append(image1)
  newList.append(image2)
  newList.append(image3)
  newList.append(image4)
  newList.append(image5)
  newImageDataList.append(newList)
newImageData = np.array(newImageDataList).astype("float32") 
print(newImageData.shape)   # 1635 images -> 327 sequences, 5 images per sequences, shape of image is 48x48x3.
newImageData /= 255    # Normalize images
numClasses = 7    # Labels of emotions
# Out:
# (327, 5, 48, 48, 3)

# %%
# Convert labels to one-hot encoding
oneHot = np_utils.to_categorical(labels, numClasses)
# Since the data is divided by 5 because they are now sequences, the labels should also be divided by 5.
# One sequence of 5 images should only have one label.
newOneHot = oneHot[0: len(oneHot): lenSequence]

# Split the dataset into training and testing
xTrain, xTest, yTrain, yTest = train_test_split(
    newImageData, newOneHot, test_size=0.15, random_state=10)
 
# Split validation data
xTrain, xValid, yTrain, yValid = train_test_split(
    xTrain, yTrain, test_size=0.15, random_state=10)

# %%
# Kernel size
# kernelSize = (2, 2)
# kernelSize = (3, 3)
kernelSize = (5, 5)
# kernelSize = (7, 7)

# %%
# Defining the model
model = Sequential()

# Convolutional layer.
model.add(TimeDistributed(Conv2D(32, kernel_size=kernelSize, activation="relu", padding="same"), input_shape=(lenSequence, 48, 48, 3)))
# Max pooling layer
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model.add(TimeDistributed(Dropout(0.2)))
print(model.output_shape)

# Convolutional layer.
model.add(TimeDistributed(Conv2D(64, kernel_size=kernelSize, activation="relu", padding="same")))
# Max pooling layer
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model.add(TimeDistributed(Dropout(0.2)))
print(model.output_shape)

# Convolutional layer.
model.add(TimeDistributed(Conv2D(128, kernel_size=kernelSize, activation="relu", padding="same")))
# Max pooling layer
model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model.add(TimeDistributed(Dropout(0.2)))
print(model.output_shape)

# Flattens the features
# The output of this layer will now be: 5 timesteps, n features.
model.add(TimeDistributed(Flatten()))
model.add((Dropout(0.2)))
print(model.output_shape)

# LSTM layer
model.add(LSTM(50))   # activation function = tanh
print(model.output_shape)

# Output layer with softmax function
model.add(Dense(numClasses, activation="softmax"))
# Out:
# (None, 5, 24, 24, 32)
# (None, 5, 12, 12, 64)
# (None, 5, 6, 6, 128)
# (None, 5, 4608)
# (None, 50)

# %%
# Compile Model
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy"])

# %%
model_hist  = model.fit(xTrain, yTrain, batch_size=50, epochs=100, verbose=1, validation_data=(xValid, yValid))
# Out:
# Epoch 1/100
# 5/5 [==============================] - 2s 151ms/step - loss: 1.9766 - accuracy: 0.1596 - val_loss: 1.8359 - val_accuracy: 0.2619
# Epoch 2/100
# 5/5 [==============================] - 0s 44ms/step - loss: 1.8545 - accuracy: 0.2575 - val_loss: 1.8079 - val_accuracy: 0.2619
# Epoch 3/100
# 5/5 [==============================] - 0s 35ms/step - loss: 1.8337 - accuracy: 0.2484 - val_loss: 1.7884 - val_accuracy: 0.2619
# Epoch 4/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.8148 - accuracy: 0.2446 - val_loss: 1.8139 - val_accuracy: 0.2143
# Epoch 5/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.7991 - accuracy: 0.2425 - val_loss: 1.7928 - val_accuracy: 0.2381
# Epoch 6/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.7723 - accuracy: 0.2684 - val_loss: 1.7852 - val_accuracy: 0.2381
# Epoch 7/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.8195 - accuracy: 0.2256 - val_loss: 1.7450 - val_accuracy: 0.2381
# Epoch 8/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.7541 - accuracy: 0.2519 - val_loss: 1.7197 - val_accuracy: 0.2143
# Epoch 9/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.7268 - accuracy: 0.2583 - val_loss: 1.7250 - val_accuracy: 0.2143
# Epoch 10/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.6250 - accuracy: 0.3803 - val_loss: 1.6517 - val_accuracy: 0.2619
# Epoch 11/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.5991 - accuracy: 0.3647 - val_loss: 1.6771 - val_accuracy: 0.2381
# Epoch 12/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.4490 - accuracy: 0.4675 - val_loss: 1.6104 - val_accuracy: 0.4286
# Epoch 13/100
# 5/5 [==============================] - 0s 33ms/step - loss: 1.4213 - accuracy: 0.4395 - val_loss: 1.5200 - val_accuracy: 0.4524
# Epoch 14/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.3416 - accuracy: 0.5164 - val_loss: 1.5091 - val_accuracy: 0.4286
# Epoch 15/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.1485 - accuracy: 0.6023 - val_loss: 1.3456 - val_accuracy: 0.5714
# Epoch 16/100
# 5/5 [==============================] - 0s 32ms/step - loss: 1.0304 - accuracy: 0.6149 - val_loss: 1.3574 - val_accuracy: 0.5238
# Epoch 17/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.9756 - accuracy: 0.6302 - val_loss: 1.1068 - val_accuracy: 0.6667
# Epoch 18/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.8138 - accuracy: 0.7208 - val_loss: 1.0177 - val_accuracy: 0.6190
# Epoch 19/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.6618 - accuracy: 0.7710 - val_loss: 1.0333 - val_accuracy: 0.5714
# Epoch 20/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.5958 - accuracy: 0.8429 - val_loss: 1.0060 - val_accuracy: 0.6667
# Epoch 21/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.5896 - accuracy: 0.7988 - val_loss: 0.9020 - val_accuracy: 0.6667
# Epoch 22/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.4654 - accuracy: 0.8699 - val_loss: 0.8064 - val_accuracy: 0.6667
# Epoch 23/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3872 - accuracy: 0.8981 - val_loss: 0.7398 - val_accuracy: 0.7619
# Epoch 24/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3802 - accuracy: 0.8823 - val_loss: 0.7923 - val_accuracy: 0.7143
# Epoch 25/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3660 - accuracy: 0.8854 - val_loss: 0.8846 - val_accuracy: 0.6905
# Epoch 26/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.3806 - accuracy: 0.8753 - val_loss: 0.7419 - val_accuracy: 0.8095
# Epoch 27/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.3244 - accuracy: 0.9007 - val_loss: 0.7571 - val_accuracy: 0.7619
# Epoch 28/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.2364 - accuracy: 0.9694 - val_loss: 0.5417 - val_accuracy: 0.8333
# Epoch 29/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.1720 - accuracy: 0.9726 - val_loss: 0.5692 - val_accuracy: 0.8333
# Epoch 30/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1649 - accuracy: 0.9681 - val_loss: 0.5231 - val_accuracy: 0.8571
# Epoch 31/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1677 - accuracy: 0.9556 - val_loss: 0.5231 - val_accuracy: 0.8333
# Epoch 32/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1400 - accuracy: 0.9689 - val_loss: 0.5670 - val_accuracy: 0.7857
# Epoch 33/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.1119 - accuracy: 0.9955 - val_loss: 0.4611 - val_accuracy: 0.8810
# Epoch 34/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.1035 - accuracy: 0.9963 - val_loss: 0.5334 - val_accuracy: 0.8333
# Epoch 35/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0761 - accuracy: 0.9857 - val_loss: 0.4907 - val_accuracy: 0.8095
# Epoch 36/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0927 - accuracy: 0.9977 - val_loss: 0.4061 - val_accuracy: 0.9048
# Epoch 37/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0759 - accuracy: 1.0000 - val_loss: 0.4350 - val_accuracy: 0.8810
# Epoch 38/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0825 - accuracy: 0.9902 - val_loss: 0.4282 - val_accuracy: 0.8571
# Epoch 39/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0603 - accuracy: 1.0000 - val_loss: 0.3796 - val_accuracy: 0.8571
# Epoch 40/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0524 - accuracy: 1.0000 - val_loss: 0.3914 - val_accuracy: 0.8810
# Epoch 41/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0477 - accuracy: 0.9977 - val_loss: 0.3547 - val_accuracy: 0.8810
# Epoch 42/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 0.3534 - val_accuracy: 0.9048
# Epoch 43/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.3848 - val_accuracy: 0.8810
# Epoch 44/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.3767 - val_accuracy: 0.9048
# Epoch 45/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.3606 - val_accuracy: 0.9048
# Epoch 46/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.3664 - val_accuracy: 0.8810
# Epoch 47/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.3820 - val_accuracy: 0.9048
# Epoch 48/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.4180 - val_accuracy: 0.8571
# Epoch 49/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0279 - accuracy: 0.9966 - val_loss: 0.3442 - val_accuracy: 0.9286
# Epoch 50/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.3659 - val_accuracy: 0.9286
# Epoch 51/100
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0281 - accuracy: 0.9966 - val_loss: 0.3955 - val_accuracy: 0.8571
# Epoch 52/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.4572 - val_accuracy: 0.8571
# Epoch 53/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.3700 - val_accuracy: 0.9048
# Epoch 54/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.3344 - val_accuracy: 0.9048
# Epoch 55/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0202 - accuracy: 0.9950 - val_loss: 0.5309 - val_accuracy: 0.8095
# Epoch 56/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.3614 - val_accuracy: 0.9048
# Epoch 57/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0301 - accuracy: 0.9916 - val_loss: 0.7160 - val_accuracy: 0.7857
# Epoch 58/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0693 - accuracy: 0.9880 - val_loss: 0.4042 - val_accuracy: 0.8810
# Epoch 59/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0326 - accuracy: 0.9977 - val_loss: 0.4097 - val_accuracy: 0.8810
# Epoch 60/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0287 - accuracy: 0.9977 - val_loss: 0.3926 - val_accuracy: 0.8571
# Epoch 61/100
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.4277 - val_accuracy: 0.8810
# Epoch 62/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.4704 - val_accuracy: 0.8571
# Epoch 63/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.3848 - val_accuracy: 0.8571
# Epoch 64/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.3372 - val_accuracy: 0.9286
# Epoch 65/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.3447 - val_accuracy: 0.9286
# Epoch 66/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.3957 - val_accuracy: 0.9048
# Epoch 67/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.4124 - val_accuracy: 0.9048
# Epoch 68/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.3737 - val_accuracy: 0.9286
# Epoch 69/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.3574 - val_accuracy: 0.9286
# Epoch 70/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.3608 - val_accuracy: 0.9286
# Epoch 71/100
# 5/5 [==============================] - 0s 35ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.3559 - val_accuracy: 0.9286
# Epoch 72/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.3348 - val_accuracy: 0.9286
# Epoch 73/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.9286
# Epoch 74/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.3530 - val_accuracy: 0.9286
# Epoch 75/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.3669 - val_accuracy: 0.9286
# Epoch 76/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.3749 - val_accuracy: 0.9286
# Epoch 77/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.3736 - val_accuracy: 0.9286
# Epoch 78/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.3684 - val_accuracy: 0.9286
# Epoch 79/100
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.3675 - val_accuracy: 0.9286
# Epoch 80/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.3611 - val_accuracy: 0.9286
# Epoch 81/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.3623 - val_accuracy: 0.9286
# Epoch 82/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.3675 - val_accuracy: 0.9286
# Epoch 83/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.3688 - val_accuracy: 0.9286
# Epoch 84/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.3719 - val_accuracy: 0.9286
# Epoch 85/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.3719 - val_accuracy: 0.9286
# Epoch 86/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.3698 - val_accuracy: 0.9286
# Epoch 87/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.3688 - val_accuracy: 0.9286
# Epoch 88/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.3746 - val_accuracy: 0.9286
# Epoch 89/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.3805 - val_accuracy: 0.9286
# Epoch 90/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.3870 - val_accuracy: 0.9286
# Epoch 91/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.3827 - val_accuracy: 0.9286
# Epoch 92/100
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.3768 - val_accuracy: 0.9286
# Epoch 93/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.3749 - val_accuracy: 0.9286
# Epoch 94/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3730 - val_accuracy: 0.9286
# Epoch 95/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3744 - val_accuracy: 0.9286
# Epoch 96/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3774 - val_accuracy: 0.9286
# Epoch 97/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.3766 - val_accuracy: 0.9286
# Epoch 98/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.3768 - val_accuracy: 0.9286
# Epoch 99/100
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.3750 - val_accuracy: 0.9286
# Epoch 100/100
# 5/5 [==============================] - 0s 33ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.3799 - val_accuracy: 0.9286

# %%
#Show the summary of the model
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_40 (TimeDis (None, 5, 48, 48, 32)     2432
# _________________________________________________________________
# time_distributed_41 (TimeDis (None, 5, 24, 24, 32)     0
# _________________________________________________________________
# time_distributed_42 (TimeDis (None, 5, 24, 24, 32)     0
# _________________________________________________________________
# time_distributed_43 (TimeDis (None, 5, 24, 24, 64)     51264
# _________________________________________________________________
# time_distributed_44 (TimeDis (None, 5, 12, 12, 64)     0
# _________________________________________________________________
# time_distributed_45 (TimeDis (None, 5, 12, 12, 64)     0
# _________________________________________________________________
# time_distributed_46 (TimeDis (None, 5, 12, 12, 128)    204928
# _________________________________________________________________
# time_distributed_47 (TimeDis (None, 5, 6, 6, 128)      0
# _________________________________________________________________
# time_distributed_48 (TimeDis (None, 5, 6, 6, 128)      0
# _________________________________________________________________
# time_distributed_49 (TimeDis (None, 5, 4608)           0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 5, 4608)           0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 50)                931800
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 357
# =================================================================
# Total params: 1,190,781
# Trainable params: 1,190,781
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create plot of accuracy by epoch
plt.plot(model_hist.history['accuracy'])
plt.plot(model_hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.figure(figsize=(20,10))
plt.show()

# %%
trainScore = model.evaluate(xTrain, yTrain, verbose=0)
print('Train loss:', trainScore[0])
print('Train accuracy:', 100*trainScore[1])

testScore = model.evaluate(xTest, yTest, verbose=0)
print('Test loss:', testScore[0])
print('Test accuracy:', 100*testScore[1])
# Out:
# Train loss: 0.002474087057635188
# Train accuracy: 100.0
# Test loss: 0.15273216366767883
# Test accuracy: 95.99999785423279
